# %% [markdown]
# <a href="https://colab.research.google.com/github/aslidagar/TechnoHacks-Intern-/blob/main/Statistics(mean%2Cmedian%2Cmode).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Name : Lakshay Dagar
# # Task - 2
# Calculating summary statistics (mean, median,mode, standard deviation) for a dataset

# %%
#Importing Python Libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import numpy as np

# %% [markdown]
# # Importing the cleaned dataset

# %%
df=pd.read_csv('/titanic cleaned data.csv')
df
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# ..          ...          ...       ...     ...
# 820         886          887         0       2
# 821         887          888         1       1
# 822         888          889         0       3
# 823         889          890         1       1
# 824         890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# ...

# %% [markdown]
# # Extracting The Shape Of The Datset

# %%
df.shape
# Out:
# (825, 13)

# %% [markdown]
# # Geting The Top 10 Rows Of The DataFrame

# %%
df.head(10)
# Out:
#    Unnamed: 0  PassengerId  Survived  Pclass  \
# 0           0            1         0       3
# 1           1            2         1       1
# 2           2            3         1       3
# 3           3            4         1       1
# 4           4            5         0       3
# 5           5            6         0       3
# 6           6            7         0       1
# 7           8            9         1       3
# 8           9           10         1       2
# 9          10           11         1       3
#
#                                                 Name     Sex        Age  \
# 0                            Braund, Mr. Owen Harris    male  22.000000
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                             Heikkinen, Miss. Laina  female  26.000000
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                           Allen, Mr. William Henry    male  35.000000
# ...

# %% [markdown]
# # Geting The Top 10 Rows From Bottom Of The DataFrame

# %%
df.tail
# Out:
# <bound method NDFrame.tail of      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# ..          ...          ...       ...     ...
# 820         886          887         0       2
# 821         887          888         1       1
# 822         888          889         0       3
# 823         889          890         1       1
# 824         890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# ...

# %% [markdown]
# # Getting the information about all columns in the DataFrame.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 825 entries, 0 to 824
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   825 non-null    int64
#  1   PassengerId  825 non-null    int64
#  2   Survived     825 non-null    int64
#  3   Pclass       825 non-null    int64
#  4   Name         825 non-null    object
#  5   Sex          825 non-null    object
#  6   Age          825 non-null    float64
#  7   SibSp        825 non-null    int64
#  8   Parch        825 non-null    int64
#  9   Ticket       825 non-null    object
#  10  Fare         825 non-null    float64
#  11  Cabin        825 non-null    object
#  12  Embarked     824 non-null    object
# dtypes: float64(2), int64(6), object(5)
# memory usage: 83.9+ KB

# %%
df.dtypes
# Out:
# Unnamed: 0       int64
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# # Counting the number of missing values in each column of the DataFrame.

# %%
df.isnull().sum()
# Out:
# Unnamed: 0     0
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       1
# dtype: int64

# %%
df["Cabin"].mode()
# Out:
# 0    B96 B98
# Name: Cabin, dtype: object

# %%
df["Cabin"].fillna(df["Cabin"].mode()[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0     0
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       1
# dtype: int64

# %% [markdown]
# # Getting all column names in the DataFrame.

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# # Count of the DataFrame

# %%
df.count()
# Out:
# Unnamed: 0     825
# PassengerId    825
# Survived       825
# Pclass         825
# Name           825
# Sex            825
# Age            825
# SibSp          825
# Parch          825
# Ticket         825
# Fare           825
# Cabin          825
# Embarked       824
# dtype: int64

# %% [markdown]
# #Mean of the DataFrame

# %%
df.mean(numeric_only='True')
# Out:
# Unnamed: 0     446.369697
# PassengerId    447.369697
# Survived         0.380606
# Pclass           2.341818
# Age             28.879689
# SibSp            0.507879
# Parch            0.357576
# Fare            32.204208
# dtype: float64

# %% [markdown]
# #Median of the DataFrame

# %%
df.median(numeric_only='True')
# Out:
# Unnamed: 0     444.000000
# PassengerId    445.000000
# Survived         0.000000
# Pclass           3.000000
# Age             29.699118
# SibSp            0.000000
# Parch            0.000000
# Fare            32.204208
# dtype: float64

# %% [markdown]
# #Mode of the DataFrame

# %%
df.mode()
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1       0.0     3.0
# 1             1            2       NaN     NaN
# 2             2            3       NaN     NaN
# 3             3            4       NaN     NaN
# 4             4            5       NaN     NaN
# ..          ...          ...       ...     ...
# 820         886          887       NaN     NaN
# 821         887          888       NaN     NaN
# 822         888          889       NaN     NaN
# 823         889          890       NaN     NaN
# 824         890          891       NaN     NaN
#
#                                       Name   Sex        Age  SibSp  Parch  \
# 0                      Abbing, Mr. Anthony  male  29.699118    0.0    0.0
# 1              Abbott, Mr. Rossmore Edward   NaN        NaN    NaN    NaN
# 2         Abbott, Mrs. Stanton (Rosa Hunt)   NaN        NaN    NaN    NaN
# 3                      Abelson, Mr. Samuel   NaN        NaN    NaN    NaN
# ...

# %% [markdown]
# #Standard Deviation of the DataFrame

# %%
df_std=df.std(numeric_only='True')
df_std
# Out:
# Unnamed: 0     2.570889e+02
# PassengerId    2.570889e+02
# Survived       4.858304e-01
# Pclass         8.240965e-01
# Age            1.018271e+01
# SibSp          1.090670e+00
# Parch          7.985995e-01
# Fare           7.109738e-15
# dtype: float64

# %% [markdown]
# #Statistical Summary Of Data Frame

# %%
df.describe()
# Out:
#        Unnamed: 0  PassengerId    Survived      Pclass         Age  \
# count  825.000000   825.000000  825.000000  825.000000  825.000000
# mean   446.369697   447.369697    0.380606    2.341818   28.879689
# std    257.088865   257.088865    0.485830    0.824096   10.182710
# min      0.000000     1.000000    0.000000    1.000000    3.000000
# 25%    225.000000   226.000000    0.000000    2.000000   22.000000
# 50%    444.000000   445.000000    0.000000    3.000000   29.699118
# 75%    670.000000   671.000000    1.000000    3.000000   34.000000
# max    890.000000   891.000000    1.000000    3.000000   54.000000
#
#             SibSp       Parch          Fare
# count  825.000000  825.000000  8.250000e+02
# mean     0.507879    0.357576  3.220421e+01
# std      1.090670    0.798599  7.109738e-15
# min      0.000000    0.000000  3.220421e+01
# 25%      0.000000    0.000000  3.220421e+01
# 50%      0.000000    0.000000  3.220421e+01
# 75%      1.000000    0.000000  3.220421e+01
# ...

# %%
df.describe(include='all')
# Out:
#         Unnamed: 0  PassengerId    Survived      Pclass  \
# count   825.000000   825.000000  825.000000  825.000000
# unique         NaN          NaN         NaN         NaN
# top            NaN          NaN         NaN         NaN
# freq           NaN          NaN         NaN         NaN
# mean    446.369697   447.369697    0.380606    2.341818
# std     257.088865   257.088865    0.485830    0.824096
# min       0.000000     1.000000    0.000000    1.000000
# 25%     225.000000   226.000000    0.000000    2.000000
# 50%     444.000000   445.000000    0.000000    3.000000
# 75%     670.000000   671.000000    1.000000    3.000000
# max     890.000000   891.000000    1.000000    3.000000
#
#                            Name   Sex         Age       SibSp       Parch  \
# count                       825   825  825.000000  825.000000  825.000000
# unique                      825     2         NaN         NaN         NaN
# ...

# %% [markdown]
# #Calculate the correlation between numeric columns in a DataFrame.

# %%
df.corr(numeric_only='True')
# Out:
#              Unnamed: 0  PassengerId  Survived    Pclass       Age     SibSp  \
# Unnamed: 0     1.000000     1.000000 -0.018151 -0.034032  0.048444 -0.053075
# PassengerId    1.000000     1.000000 -0.018151 -0.034032  0.048444 -0.053075
# Survived      -0.018151    -0.018151  1.000000 -0.367774 -0.027320 -0.030860
# Pclass        -0.034032    -0.034032 -0.367774  1.000000 -0.286128  0.057760
# Age            0.048444     0.048444 -0.027320 -0.286128  1.000000 -0.182124
# SibSp         -0.053075    -0.053075 -0.030860  0.057760 -0.182124  1.000000
# Parch         -0.006142    -0.006142  0.074199  0.018742 -0.131052  0.408487
# Fare                NaN          NaN       NaN       NaN       NaN       NaN
#
#                 Parch  Fare
# Unnamed: 0  -0.006142   NaN
# PassengerId -0.006142   NaN
# Survived     0.074199   NaN
# Pclass       0.018742   NaN
# Age         -0.131052   NaN
# SibSp        0.408487   NaN
# Parch        1.000000   NaN
# Fare              NaN   NaN

# %% [markdown]
# #Creates a separate groups for each survival outcome (survived and not survived).

# %%
### Overview(Survived vs non survied)
survived_summary= df.groupby("Survived")
survived_summary.mean(numeric_only='True').reset_index()
# Out:
#    Survived  Unnamed: 0  PassengerId    Pclass        Age     SibSp     Parch  \
# 0         0  450.025440   451.025440  2.579256  29.097632  0.534247  0.311155
# 1         1  440.420382   441.420382  1.955414  28.525013  0.464968  0.433121
#
#         Fare
# 0  32.204208
# 1  32.204208

# %% [markdown]
# # Creates a separate groups for each survival outcome (Male & Female).

# %%
survived_summary = df.groupby("Sex")
survived_summary.mean(numeric_only='True').reset_index()
# Out:
#       Sex  Unnamed: 0  PassengerId  Survived    Pclass        Age     SibSp  \
# 0  female  431.965986   432.965986  0.741497  2.166667  28.076712  0.687075
# 1    male  454.344633   455.344633  0.180791  2.438795  29.324276  0.408663
#
#       Parch       Fare
# 0  0.639456  32.204208
# 1  0.201507  32.204208
